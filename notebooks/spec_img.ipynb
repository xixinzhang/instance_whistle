# %%
import numpy as np
import os
import glob
import json

# %%
directory = '~/Desktop/projects/whistle_prompter/data/spec_img'

# count the number of image files in the directory
img_list = glob.glob(os.path.expanduser(directory) + '/*.png')
img_count = len(img_list)
print(f'There are {img_count} images in the {directory} folder.')

with open(os.path.expanduser(directory) + '/annotations.json', 'r') as f:
    annos = json.load(f)
len(annos['annotations'])
# Out:
# There are 1646 images in the ~/Desktop/projects/whistle_prompter/data/spec_img folder.
# 10494
